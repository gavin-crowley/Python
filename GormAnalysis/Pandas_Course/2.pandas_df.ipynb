# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([['b',23],['c',23],['d',23]])
print(df)
# Out:
#    0   1
# 0  b  23
# 1  c  23
# 2  d  23

# %%
df.info()
df.shape()
df.axes
df.size

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# 'c:\\Users\\gavin\\Documents\\Python\\GormAnalysis\\Pandas_Course'

# %%
df['shrimp']
df.shrimp
# Out:
# KeyboardInterrupt

# %%
df[['shrimp', 'crab']]
df.iloc[0,2,4]
df.iloc[0:5:2]
df.iloc[[1]] # row 2
df.iloc[:,[0,1]] # cols 0 and 1
df.iloc[[0,2],[1,2]] # rows 0 2 with cols 1 2

# %%
df.loc['b','e']
