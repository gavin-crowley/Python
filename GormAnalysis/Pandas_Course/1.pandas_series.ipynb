# %%
# series creation

# %%
import pandas as pd

# %%
x = pd.Series([10,20,30,40,50,60,70])

# %%
print(x)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x.dtype
# Out:
# dtype('int64')

# %%
x.to_numpy()
# Out:
# array([10, 20, 30, 40, 50, 60, 70], dtype=int64)

# %%
x.head()
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
x.tail()
# Out:
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
x.head(2)
# Out:
# 0    10
# 1    20
# dtype: int64

# %%
data = {'a': 0, 'b': 1, 'c': 2}
y = pd.Series(data)
print(y)
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
z = pd.Series(['a','b','c'], dtype='string')
print(z)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
import numpy as np

# %%
x = np.array([10,20,30,40,50])

# %%
x = pd.Series(x)

# %%
# series basic indexing

# %%
x.iloc[1]
# Out:
# 20

# %%
x.iloc[-1]
# Out:
# 50

# %%
# .loc for label index, .iloc for positional index
# positional slicing excludes the right boundary, label slicing doesn't

# %%
import sys

# %%
sys.getsizeof(x)
# Out:
# 164

# %%
x.iloc[1] = 200

# %%
x
# Out:
# 0     10
# 1    200
# 2     30
# 3     40
# 4     50
# dtype: int32

# %%
x.iloc[[0,1,2]] = 99
x
# Out:
# 0    99
# 1    99
# 2    99
# 3    40
# 4    50
# dtype: int32

# %%
x.iloc[:3] = 999
x
# Out:
# 0    999
# 1    999
# 2    999
# 3     40
# 4     50
# dtype: int32

# %%
new_vals = np.array([100,200,300,400,500
                     ])

# %%
x.iloc[:] = new_vals
x
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int32

# %%
# series basic operations

# %%
# adding two series is done by index label
# to add by position just defer to numpy, a.to_numpy() + b.to_numpy()

# %%
# series boolean indexing

# %%
x < 300
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# series missing values

# %%
# nan is a float
# dtype='Int64' prevents casting to float

# %%
pd.isna(x)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
pd.notna(x)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
# series vectorization

# %%
x.mean()
# Out:
# 300.0

# %%
# series apply()

# %%
def my_func(x, a=1, b=3):
    return x - a if x % 2 == 0 else x + b

# %%
x.apply(my_func)
# Out:
# 0     99
# 1    199
# 2    299
# 3    399
# 4    499
# dtype: int64

# %%
# series view vs copy

# %%
# y = x -> assignment by reference, y is a view of x, not a copy
# a copy -> y = x.copy()

# %%
# Challenge 1

import numpy as np
import pandas as pd

babynames = pd.Series([
    'Jathonathon', 'Zeltron', 'Ruger', 'Phreddy', 'Ruger', 'Chad', 'Chad',
    'Ruger', 'Ryan', 'Ruger', 'Chad', 'Ryan', 'Phreddy', 'Phreddy', 'Phreddy',
    'Mister', 'Zeltron', 'Ryan', 'Ruger', 'Ruger', 'Jathonathon',
    'Jathonathon', 'Ruger', 'Chad', 'Zeltron'], dtype='string')

#Determine how many people voted for the names ‘Chad’, ‘Ruger’, and ‘Zeltron’.

# %%
type(babynames)
# Out:
# pandas.core.series.Series

# %%
babynames.dtype
# Out:
# string[python]

# %%
babynames.str.count('Chad').sum()
# Out:
# 4

# %%
babynames.str.count('Ruger').sum()
# Out:
# 7

# %%
babynames.str.count('Zeltron').sum()
# Out:
# 3

# %%
babynames.value_counts().loc[['Chad', 'Ruger', 'Zeltron']]
# Out:
# Chad       4
# Ruger      7
# Zeltron    3
# dtype: Int64

# %%
# Challenge 2

bees = pd.Series([True, True, False, np.nan, True, False, True, np.nan])
knees = pd.Series([5,2,9,1,3,10,5,2], index = [7,0,2,6,3,5,1,4])

# Given, two Series bees and knees, if the ith value of bees is NaN,
# double the ith value inside knees.

print(bees)
# Out:
# 0     True
# 1     True
# 2    False
# 3      NaN
# 4     True
# 5    False
# 6     True
# 7      NaN
# dtype: object

# %%
print(knees)
# Out:
# 7     5
# 0     2
# 2     9
# 6     1
# 3     3
# 5    10
# 1     5
# 4     2
# dtype: int64

# %%
bees.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# dtype: bool

# %%
pd.isna(bees).to_numpy()
# Out:
# array([False, False, False,  True, False, False, False,  True])

# %%
knees.loc[pd.isna(bees).to_numpy()] *= 2
print(knees)
# Out:
# 7     5
# 0     2
# 2     9
# 6     4
# 3     3
# 5    10
# 1     5
# 4     8
# dtype: int64

# %%
# Challenge 3
asking_prices = pd.Series([5000, 7600, 9000, 8500, 7000], index=['civic', 'civic', 'camry', 'mustang', 'mustang'])
fair_prices = pd.Series([5500, 7500, 7500], index=['civic', 'mustang', 'camry'])

print(asking_prices)
# Out:
# civic      5000
# civic      7600
# camry      9000
# mustang    8500
# mustang    7000
# dtype: int64

# %%
print(fair_prices)
# Out:
# civic      5500
# mustang    7500
# camry      7500
# dtype: int64

# %%
all_fair_prices = fair_prices.loc[asking_prices.index]
print(all_fair_prices)
# Out:
# civic      5500
# civic      5500
# camry      7500
# mustang    7500
# mustang    7500
# dtype: int64

# %%
off_market_prices = asking_prices - all_fair_prices
print(off_market_prices)
# Out:
# civic      -500
# civic      2100
# camry      1500
# mustang    1000
# mustang    -500
# dtype: int64

# %%
below_fair_prices = (off_market_prices < 0).reset_index(drop=True)
print(below_fair_prices)
# replaces index from label to position
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
sol = below_fair_prices.loc[below_fair_prices].index
print(sol)
# Out:
# Int64Index([0, 4], dtype='int64')
