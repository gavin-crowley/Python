# %%
# My New Notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
x = 10
x
# Out:
# 10

# %%
y = 3
y
# Out:
# 3

# %%
print ( x**2)
# Out:
# 100

# %% [markdown]
# Hey

# %% [markdown]
# # Python
# ## Lists
# ### Methods
# #### Functions

# %% [markdown]
# **This is bold and *italic***

# %% [markdown]
# Unordered list:
# - one
# - two
# - three

# %% [markdown]
# `append()` is a list method

# %%
x**2
# Out:
# 100
